# %%
# 忽略警告信息
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import copy
import shap
import lightgbm as lgb
import sklearn.preprocessing 
import sklearn.feature_selection
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from scipy.stats.stats import spearmanr, pearsonr
import joblib

# %%
#Random seed
SEED = np.random.seed(2020)

# %%
############ Data Processing ###########
print("\n...... Processing Data ......\n")

#Load data
GTEx = pd.read_csv('/home/lilabguest2/shenhaoyu/GTEx_feature_river',sep = '\t',index_col=0)
GTEx=GTEx.iloc[:,:-1]
GTEx
# Out:
# ...... Processing Data ......
#                       GeneName        GC       CpG   fitCons     PHRED  \
# SubjectID
# GTEX-111CU   ENSG00000000457.9  1.057671  1.070147  0.106686  0.854062
# GTEX-111VG   ENSG00000000457.9 -0.295611 -0.766125  6.709830 -0.497586
# GTEX-111YS   ENSG00000000457.9 -0.633932 -0.503801  0.106686 -0.570891
# GTEX-1122O   ENSG00000000457.9  2.241793  1.594796  6.947333  0.230385
# GTEX-113JC   ENSG00000000457.9 -1.225993 -0.503801 -0.014524  0.995355
# ...                        ...       ...       ...       ...       ...
# GTEX-X261    ENSG00000213077.5 -0.041871 -0.503801  2.247992  1.085079
# GTEX-XAJ8    ENSG00000213077.5 -0.041871 -0.503801  2.247992  1.085079
# GTEX-RN64   ENSG00000178115.10  1.226831  1.070147 -0.167308 -0.470067
# GTEX-XUZC    ENSG00000184779.8  2.664693  4.742690 -0.308792 -0.076713
# GTEX-Y8LW   ENSG00000174194.11  0.719350  0.545497 -0.308792 -0.836365
#
# ...

# %%
GTEx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3862043 entries, GTEX-111CU to GTEX-Y8LW
# Data columns (total 25 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   GeneName                       object
#  1   GC                             float64
#  2   CpG                            float64
#  3   fitCons                        float64
#  4   PHRED                          float64
#  5   DANN                           float64
#  6   phylop                         float64
#  7   GerpN                          float64
#  8   GerpS                          float64
#  9   TFBS                           float64
#  10  EncOCpolIISig                  float64
#  11  EncOCDNaseSig                  float64
#  12  EncOCFaireSig                  float64
#  13  EncH3K4Me3                     float64
#  14  coding                         int64
#  15  frameshift                     int64
#  16  splice                         int64
# ...

# %%
GTEx.describe(include='all')#描述性统计
# Out:
#                  GeneName            GC           CpG       fitCons  \
# count             3862043  3.862043e+06  3.862043e+06  3.862043e+06
# unique              14117           NaN           NaN           NaN
# top     ENSG00000185052.7           NaN           NaN           NaN
# freq                  474           NaN           NaN           NaN
# mean                  NaN  5.925536e-01  6.601087e-01  6.361898e-01
# std                   NaN  1.001993e+00  1.416041e+00  1.700942e+00
# min                   NaN -3.002175e+00 -7.661250e-01 -9.866120e-01
# 25%                   NaN -4.187100e-02 -5.038010e-01 -1.593980e-01
# 50%                   NaN  7.193500e-01  2.831730e-01  1.066860e-01
# 75%                   NaN  1.226831e+00  1.332471e+00  4.049910e-01
# max                   NaN  3.764235e+00  1.182545e+01  7.734053e+00
#
#                PHRED          DANN        phylop         GerpN         GerpS  \
# ...

# %%
GTEx.hist(bins=40, figsize=(20,15))#观察分布情况，服从什么分布（正态，长尾，双峰），是否有异常
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7ef6cb2f98>,
# ...
#       dtype=object)

# %% [markdown]
# 相关性分析

# %%
corrMat = GTEx.corr()
#plt.figure(figsize=(40,20))
sn.clustermap(corrMat,cmap= "RdBu_r",center=0,annot=True, square=True,figsize=(18,18))#线性模型中应再去掉相关性强的特征

# %%
GTEx['out']=GTEx['Zscore'].apply(lambda x : 1 if abs(x) >=2 else 0)
GTEx
# Out:
#                       GeneName        GC       CpG   fitCons     PHRED  \
# SubjectID
# GTEX-111CU   ENSG00000000457.9  1.057671  1.070147  0.106686  0.854062
# GTEX-111VG   ENSG00000000457.9 -0.295611 -0.766125  6.709830 -0.497586
# GTEX-111YS   ENSG00000000457.9 -0.633932 -0.503801  0.106686 -0.570891
# GTEX-1122O   ENSG00000000457.9  2.241793  1.594796  6.947333  0.230385
# GTEX-113JC   ENSG00000000457.9 -1.225993 -0.503801 -0.014524  0.995355
# ...                        ...       ...       ...       ...       ...
# GTEX-X261    ENSG00000213077.5 -0.041871 -0.503801  2.247992  1.085079
# GTEX-XAJ8    ENSG00000213077.5 -0.041871 -0.503801  2.247992  1.085079
# GTEX-RN64   ENSG00000178115.10  1.226831  1.070147 -0.167308 -0.470067
# GTEX-XUZC    ENSG00000184779.8  2.664693  4.742690 -0.308792 -0.076713
# GTEX-Y8LW   ENSG00000174194.11  0.719350  0.545497 -0.308792 -0.836365
#
#                 DANN    phylop     GerpN     GerpS     TFBS  ...  splice  \
# ...

# %% [markdown]
# 统计E-outlier个数，共发现5020个E-outlier

# %%
GTEx['out'].value_counts()
# Out:
# 0    3857023
# 1       5020
# Name: out, dtype: int64

# %%
GTEx_outlier=GTEx[GTEx['out']==1]
GTEx_outlier
# Out:
#                       GeneName        GC       CpG   fitCons     PHRED  \
# SubjectID
# GTEX-111YS  ENSG00000001461.12  0.550190 -0.503801 -0.014524 -0.307731
# GTEX-14E6C  ENSG00000003436.10 -0.464771  0.545497 -0.397834 -0.031157
# GTEX-15UF7  ENSG00000003509.11 -0.633932  0.020848  0.813832  0.817756
# GTEX-1B996  ENSG00000003756.12  0.042709  0.545497  1.835257  0.061111
# GTEX-ZTTD    ENSG00000004478.5  0.042709 -0.503801 -0.096654 -0.322530
# ...                        ...       ...       ...       ...       ...
# GTEX-17EVQ   ENSG00000204790.8 -0.633932 -0.503801 -0.167308 -0.671947
# GTEX-PWN1    ENSG00000235173.2 -1.310573 -0.766125 -0.308792 -0.193263
# GTEX-RUSQ    ENSG00000235173.2  0.973091  1.594796 -0.397834 -0.736697
# GTEX-1EH9U   ENSG00000232653.4 -0.718512 -0.766125 -0.167308 -0.961239
# GTEX-XAJ8    ENSG00000232653.4 -1.564313 -0.766125 -0.120659  0.565695
#
#                 DANN    phylop     GerpN     GerpS     TFBS  ...  splice  \
# ...

# %%
#Control samples
GTEx_ctr = GTEx[GTEx["out"] == 0] 
GTEx_ctr = GTEx_ctr.sample(len(GTEx_outlier),random_state = SEED) 
#Concat case and partial control
GTEx_dataset = pd.concat([GTEx_outlier,GTEx_ctr]) 
GTEx_dataset
# Out:
#                       GeneName        GC       CpG   fitCons     PHRED  \
# SubjectID
# GTEX-111YS  ENSG00000001461.12  0.550190 -0.503801 -0.014524 -0.307731
# GTEX-14E6C  ENSG00000003436.10 -0.464771  0.545497 -0.397834 -0.031157
# GTEX-15UF7  ENSG00000003509.11 -0.633932  0.020848  0.813832  0.817756
# GTEX-1B996  ENSG00000003756.12  0.042709  0.545497  1.835257  0.061111
# GTEX-ZTTD    ENSG00000004478.5  0.042709 -0.503801 -0.096654 -0.322530
# ...                        ...       ...       ...       ...       ...
# GTEX-14PN4   ENSG00000167034.9  1.311411 -0.503801 -0.265785  0.563614
# GTEX-RM2N   ENSG00000125485.13  1.057671  0.283173  0.106686  0.217897
# GTEX-13FTW  ENSG00000101224.13  1.311411  0.545497  6.385292  2.619644
# GTEX-R55G   ENSG00000186318.12  1.734312  1.332471  0.404991  0.657501
# GTEX-11TT1  ENSG00000143363.11  0.381030  0.020848 -0.167308  0.310628
#
#                 DANN    phylop     GerpN     GerpS      TFBS  ...  splice  \
# ...

# %%
GTEx_dataset.head(10)
# Out:
#                       GeneName        GC       CpG   fitCons     PHRED  \
# SubjectID
# GTEX-111YS  ENSG00000001461.12  0.550190 -0.503801 -0.014524 -0.307731
# GTEX-14E6C  ENSG00000003436.10 -0.464771  0.545497 -0.397834 -0.031157
# GTEX-15UF7  ENSG00000003509.11 -0.633932  0.020848  0.813832  0.817756
# GTEX-1B996  ENSG00000003756.12  0.042709  0.545497  1.835257  0.061111
# GTEX-ZTTD    ENSG00000004478.5  0.042709 -0.503801 -0.096654 -0.322530
# GTEX-15UKP  ENSG00000004534.10 -0.211031 -0.766125  0.177461 -0.677034
# GTEX-13G51  ENSG00000004660.10  2.495533  4.218041 -0.397834 -0.268418
# GTEX-Y8LW    ENSG00000004864.9  0.634770  1.070147  0.813832  2.957267
# GTEX-YEC3    ENSG00000005243.5  2.072633  4.480366  0.847283  2.337521
# GTEX-1A3MV  ENSG00000005700.10 -0.549351 -0.503801  6.947333  8.460982
#
#                 DANN    phylop     GerpN     GerpS      TFBS  ...  splice  \
# SubjectID                                                     ...
# ...

# %%
GTEx_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10040 entries, GTEX-111YS to GTEX-11TT1
# Data columns (total 26 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   GeneName                       10040 non-null  object
#  1   GC                             10040 non-null  float64
#  2   CpG                            10040 non-null  float64
#  3   fitCons                        10040 non-null  float64
#  4   PHRED                          10040 non-null  float64
#  5   DANN                           10040 non-null  float64
#  6   phylop                         10040 non-null  float64
#  7   GerpN                          10040 non-null  float64
#  8   GerpS                          10040 non-null  float64
#  9   TFBS                           10040 non-null  float64
#  10  EncOCpolIISig                  10040 non-null  float64
#  11  EncOCDNaseSig                  10040 non-null  float64
# ...

# %%
GTEx_dataset.hist(bins=40, figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7d3432aba8>,
# ...
#       dtype=object)

# %%
GTEx_dataset.iloc[:,:-1].drop(['upstream_downstream10kb_200kb'],axis=1).to_csv('/home/lilabguest2/shenhaoyu/GTEx_dataset', sep='\t',na_rep='NA', header=True, index=True)

# %%
corrMat = GTEx_dataset.drop(['upstream_downstream10kb_200kb'],axis=1).corr()
#plt.figure(figsize=(40,20))
sn.clustermap(corrMat,cmap= "RdBu_r",center=0,annot=True, square=True,figsize=(18,18))#线性模型中应再去掉相关性强的特征

# %%
corrMat = GTEx_outlier.drop(['upstream_downstream10kb_200kb','out','N2pair'],axis=1).corr()
#plt.figure(figsize=(40,20))
sn.clustermap(corrMat,cmap= "RdBu_r",center=0,annot=True, square=True,figsize=(18,18))#线性模型中应再去掉相关性强的特征

# %%
corrMat = GTEx_ctr.drop(['upstream_downstream10kb_200kb','out','N2pair'],axis=1).corr()
#plt.figure(figsize=(40,20))
sn.clustermap(corrMat,cmap= "RdBu_r",center=0,annot=True, square=True,figsize=(18,18))#线性模型中应再去掉相关性强的特征

# %%
GTEx_feature=GTEx_dataset.drop(['Zscore','N2pair','out','upstream_downstream10kb_200kb','GeneName'],axis=1)
GTEx_feature
# Out:
#                   GC       CpG   fitCons     PHRED      DANN    phylop  \
# SubjectID
# GTEX-111YS  0.550190 -0.503801 -0.014524 -0.307731  0.160735  0.481219
# GTEX-14E6C -0.464771  0.545497 -0.397834 -0.031157  0.994042 -7.040885
# GTEX-15UF7 -0.633932  0.020848  0.813832  0.817756  0.767738  0.220480
# GTEX-1B996  0.042709  0.545497  1.835257  0.061111  0.780348 -0.066584
# GTEX-ZTTD   0.042709 -0.503801 -0.096654 -0.322530 -0.030784  0.041967
# ...              ...       ...       ...       ...       ...       ...
# GTEX-14PN4  1.311411 -0.503801 -0.265785  0.563614  0.546804  0.341653
# GTEX-RM2N   1.057671  0.283173  0.106686  0.217897  0.639532  0.188023
# GTEX-13FTW  1.311411  0.545497  6.385292  2.619644  1.065767  0.355718
# GTEX-R55G   1.734312  1.332471  0.404991  0.657501  0.935552  0.224087
# GTEX-11TT1  0.381030  0.020848 -0.167308  0.310628  0.758004  0.496365
#
#                GerpN     GerpS      TFBS  EncOCpolIISig  ...  EncOCFaireSig  \
# ...

# %%
out=GTEx_dataset['out']
out
# Out:
# SubjectID
# GTEX-111YS    1
# GTEX-14E6C    1
# GTEX-15UF7    1
# GTEX-1B996    1
# GTEX-ZTTD     1
#              ..
# GTEX-14PN4    0
# GTEX-RM2N     0
# GTEX-13FTW    0
# GTEX-R55G     0
# GTEX-11TT1    0
# Name: out, Length: 10040, dtype: int64

# %%
#Input
X = copy.deepcopy(GTEx_feature)#经过deepcopy的操作的不管是内层还是外层数据对象都拥有不同的地址空间，修改其中的值不会对两个对象都造成影响
y = copy.deepcopy(out)
#拷贝一份用于输入

# %%
#TrainingSet : TestSet = 4 : 1
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = SEED)
print("\n...... Finished Data Processing ......\n")
########################################
# Out:
# ...... Finished Data Processing ......

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=20)
## 训练集降维
X_train_pca = pca.fit_transform(X_train)
## 测试集降维
X_test_pca = pca.transform(X_test)
# 查看方差贡献率
sum(pca.explained_variance_ratio_)
# Out:
# 0.9998341450566084

# %%
#PCA二维可视化
X_train_pca=PCA(n_components=2).fit_transform(X_train)
# 根据主成分分析结果绘制散点图
plt.scatter(X_train_pca[:,0],X_train_pca[:,1] ,c=y_train)
# 设置坐标标签
plt.xlabel('PC1')
plt.ylabel('PC2')
# 设置标题
plt.title("PCA Scatter Plot")
# 显示图形
plt.show()

# %%
########## Model Construction ##########
print("\n...... Training Model ......\n")

# LightGBM params
param_dict = {
    "learning_rate":[0.1, 0.05, 0.02, 0.015, 0.01],#学习率
    "num_leaves": range(10,36,5),# Maximum tree leaves for base learners.
    "max_depth" : [-1,2,3,4,5,10,20,40,50],#Maximum tree depth for base learners, <=0 means no limit.
    "min_data_in_leaf": range(1, 45, 2),#
    "feature_fraction" : [i / 10 for i in range(2,11)],#
    "metric" : ["binary_logloss"],#
    "early_stopping_rounds" : [None],#
    "n_jobs" : [-1],#
    "silent" : [True],#
    "verbose" : [-1],#
    "n_estimators" : range(50,1000,50),#
    "bagging_fraction" :  [i / 10 for i in range(2, 11)],#
    "bagging_freq" : [0, 1, 2],#
    "lambda_l1" : [0, 0.001, 0.005, 0.01, 0.1],#
    "lambda_l2" : [0, 0.001, 0.005, 0.01, 0.1],#
    "objective":["binary"],#
    "random_state":[2020]#
}#参数列表

#Initiate model
model = lgb.LGBMClassifier()#创建一个分类器对象
# Out:
# ...... Training Model ......

# %%
#Adjust hyper-parameters with 5-fold cross validation
rscv = RandomizedSearchCV(model,#
                          param_dict,#
                          n_iter=100,# Number of parameter settings that are sampled. n_iter tradesoff runtime vs quality of the solution.
                          cv = 5,# Determines the cross-validation splitting strategy.
                          verbose = 0,# Controls the verbosity: the higher, the more messages.
                          scoring = "roc_auc",#
                          n_jobs =-1#
                         )#用分类器对象创建一个RandomizedSearchCV的对象
gbm=rscv.fit(X_train, y_train)#得到训练后的模型
# Out:
# Found `early_stopping_rounds` in params. Will use it instead of argument
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] lambda_l1 is set=0.005, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.005
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.01, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01

# %%
########## Model Evaluation ##########
print("\n...... Evaluating Model ......\n")

#Get best model with score [max(mean(auc(5 cross validation)))]
best_model = rscv.best_estimator_
#Get predict_class(y_pred) and predict_probality_for_case(y_prob) of TestSet
y_pred = best_model.predict(X_test)
print(y_pred)
y_prob = best_model.predict_proba(X_test)[:,1]
y_prob#probability of prediction as positive,len:40(test set)
# Out:
# ...... Evaluating Model ......
#
# [1 0 0 ... 0 0 0]
# array([0.89236397, 0.34317025, 0.34158255, ..., 0.37468724, 0.48953498,
#        0.32408792])

# %%
#绘制学习曲线
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)
train_sizes, train_scores, CV_scores=learning_curve(best_model,X_train,y_train,cv=cv,train_sizes=np.linspace(.1, 1.0, 5),scoring='neg_mean_squared_error')#(.1, 1.0, 5)设步长，0.1开始到1，分五份
# Out:
# Found `early_stopping_rounds` in params. Will use it instead of argument
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# [LightGBM] [Warning] bagging_fraction is set=0.6, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6
# [LightGBM] [Warning] lambda_l1 is set=0.005, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.005
# [LightGBM] [Warning] min_data_in_leaf is set=11, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=11
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.01, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01
# Found `early_stopping_rounds` in params. Will use it instead of argument
# [LightGBM] [Warning] feature_fraction is set=0.6, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6
# ...

# %%
train_scores_mean = np.mean(train_scores, axis=1)
train_scores_std = np.std(train_scores, axis=1)
CV_scores_mean = np.mean(CV_scores, axis=1)
CV_scores_std = np.std(CV_scores, axis=1)
plt.grid()
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
plt.fill_between(train_sizes, CV_scores_mean - CV_scores_std,
                     CV_scores_mean + CV_scores_std, alpha=0.1, color="g")
plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
plt.plot(train_sizes, CV_scores_mean, 'o-', color="g",
             label="Cross-validation score")
plt.legend(loc="best")

# %%
#Evaluate performance of model
#返回auroc/auroc_curve、auprc/auprc_curve、accuracy、recall、precision、f1、class_report
def evaluate_performance(y_test, y_pred, y_prob):
    # AUROC
    auroc = metrics.roc_auc_score(y_test,y_prob)
    auroc_curve = metrics.roc_curve(y_test, y_prob)
    # AUPRC
    auprc=metrics.average_precision_score(y_test, y_prob) 
    auprc_curve=metrics.precision_recall_curve(y_test, y_prob)
    #Accuracy
    accuracy=metrics.accuracy_score(y_test,y_pred) 

    recall=metrics.recall_score(y_test, y_pred)
    precision=metrics.precision_score(y_test, y_pred)
    f1=metrics.f1_score(y_test, y_pred)
    class_report=metrics.classification_report(y_test, y_pred,target_names = ["control","case"])

    model_perf = {"auroc":auroc,"auroc_curve":auroc_curve,
                  "auprc":auprc,"auprc_curve":auprc_curve,
                  "accuracy":accuracy,
                  "recall":recall,"precision":precision,"f1":f1,
                  "class_report":class_report}
        
    return model_perf

# %%
# Output result of evaluation
#生成文件可以用于作图（bar plot consisted of accuracy,sensitivity,specificity,auroc,f1 score,precision,recall,auprc ）
def eval_output(model_perf,output_file):
    with open(output_file,'w') as f:
        f.write("AUROC=%s\tAUPRC=%s\tAccuracy=%s\tRecall=%s\tPrecision=%s\tf1_score=%s\n" %
               (model_perf["auroc"],model_perf["auprc"],model_perf["accuracy"],model_perf["recall"],model_perf["precision"],model_perf["f1"]))
        f.write("\n######NOTE#######\n")
        f.write("#According to help_documentation of sklearn.metrics.classification_report:in binary classification, recall of the positive class is also known as sensitivity; recall of the negative class is specificity#\n\n")
        f.write(model_perf["class_report"])

# %%
#Get model performance
model_perf = evaluate_performance(y_test,y_pred,y_prob)
#Output result of evaluation
eval_output(model_perf,"./Evaluate_Result_TestSet.txt")
#You can make bar plot consisted of accuracy,sensitivity,specificity,auroc,f1 score,precision,recall,auprc according to the "Evaluate_Result_TestSet.txt"

# %%
# Plot AUROC of model
def plot_AUROC(model_perf,output_file):
    #get AUROC,FPR,TPR and threshold
    roc_auc = model_perf["auroc"]
    fpr,tpr,threshold = model_perf["auroc_curve"]
    #plot
    plt.figure()
    lw = 2
    plt.figure(figsize=(10,10))
    plt.plot(fpr, tpr, color='darkorange',
             lw=lw, label='AUROC (area = %0.2f)' % roc_auc) #%相当于format方法,格式化输出,替换%***
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC of Models")
    plt.legend(loc="lower right")
    plt.savefig(output_file,format = "pdf")

# %%
# Plot AUPRC of model
def plot_AUPRC(model_perf,output_file):
    #get AUPRC,Precision,Recall and threshold
    prc_auc = model_perf["auprc"]
    precision,recall,threshold = model_perf["auprc_curve"]
    #plot
    plt.figure()
    lw = 2
    plt.figure(figsize=(10,10))#设置figure的宽、长
    plt.plot(recall, precision, color="red",
             lw=lw,#折线图的线条宽度
             label='AUPRC (area = %0.2f)' % prc_auc#图例
            ) 
    plt.plot([0, 1], [1, 0], color="navy", lw=lw, linestyle='--')#对角线
    #设置x、y坐标轴的范围
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    #坐标轴标签
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.title("AUPRC of Models")
    plt.legend(loc="lower right")
    plt.savefig(output_file,format = "pdf")

# %%
#Plot
# plot AUROC AUPRC
plot_AUROC(model_perf,"./AUROC_TestSet.pdf")
plot_AUPRC(model_perf,"./AUPRC_TestSet.pdf")

print("\n...... Finished Model Evaluation ......\n")
######################################
# Out:
# ...... Finished Model Evaluation ......

# %%
######## Model Interpretation ########

print("\n...... Interpreting Model ......\n")

# load JS visualization code to notebook
shap.initjs()
# Out:
# ...... Interpreting Model ......
# ...

# %%
#Explain the model's predictions on the entire dataset for cancer case
explainer = shap.TreeExplainer(rscv.best_estimator_) # 初始化解释器
explainer.shap_values(X)#计算每个样本的每个特征的SHAP值
#给定当前的一组特征值，特征值对实际预测值与平均预测值之差的贡献就是估计的Shap值
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
# [array([[-0.0299706 ,  0.03994901,  0.17041067, ...,  0.03687766,
#           0.0005609 ,  0.08775314],
#         [-0.03630408,  0.02891378,  0.07223415, ...,  0.02821306,
#           0.00113458,  0.02599135],
#         [-0.01817384,  0.05591479, -0.31136204, ...,  0.02988499,
#           0.00078479,  0.12285265],
#         ...,
#         [ 0.02458851,  0.06185708, -0.42880597, ...,  0.04346347,
#           0.00147621, -0.05720875],
#         [-0.07199114,  0.02877604,  0.00132551, ...,  0.03275589,
#           0.00056071, -0.05381639],
#         [ 0.03145475,  0.07411389,  0.18586731, ...,  0.0351163 ,
#           0.00048563,  0.00829274]]),
#  array([[ 0.0299706 , -0.03994901, -0.17041067, ..., -0.03687766,
#          -0.0005609 , -0.08775314],
#         [ 0.03630408, -0.02891378, -0.07223415, ..., -0.02821306,
#          -0.00113458, -0.02599135],
# ...

# %%
shap_values = explainer.shap_values(X)[1]
shap_values#每个列表为一个样本
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
# array([[ 0.0299706 , -0.03994901, -0.17041067, ..., -0.03687766,
#         -0.0005609 , -0.08775314],
#        [ 0.03630408, -0.02891378, -0.07223415, ..., -0.02821306,
#         -0.00113458, -0.02599135],
#        [ 0.01817384, -0.05591479,  0.31136204, ..., -0.02988499,
#         -0.00078479, -0.12285265],
#        ...,
#        [-0.02458851, -0.06185708,  0.42880597, ..., -0.04346347,
#         -0.00147621,  0.05720875],
#        [ 0.07199114, -0.02877604, -0.00132551, ..., -0.03275589,
#         -0.00056071,  0.05381639],
#        [-0.03145475, -0.07411389, -0.18586731, ..., -0.0351163 ,
#         -0.00048563, -0.00829274]])

# %%
#Plot the SHAP values of every feature(top 10) for every sample
print("\nThis is an overview of which features are most important(top 10) represented by \
SHAP values of every feature for every sample\n")
shap.summary_plot(shap_values, X,max_display = 10)
#把所有的样本点都呈现在图中
#如图，此时颜色代表特征值的大小，而横坐标为shap值的大小
#从图中可以看到fitCons这一特征，值越大，shap值越大，换句话来说就是fitCons越小，风险越高。
# Out:
# This is an overview of which features are most important(top 10) represented by SHAP values of every feature for every sample

# %%
#Plot the mean absolute value of the SHAP values for each feature(top 10)
print("\nThis is an overview of which features are most important(top 10) represented by \
 mean absolute value of the SHAP values for each feature\n")
shap.summary_plot(shap_values, X,plot_type="bar",max_display = 10)
#该图是对全部样本全部特征的shaple值进行求和，可以反映出特征重要性及每个特征对样本正负预测的贡献。
#If you want to save shap plot as pdf,just modify the following code
#fig = shap.summary_plot(shap_values, X, show=False,max_display = 10)
#plt.savefig("shap.pdf", format='pdf', dpi=1000, bbox_inches='tight')
# Out:
# This is an overview of which features are most important(top 10) represented by  mean absolute value of the SHAP values for each feature

# %%
sn.pairplot(GTEx_feature[['fitCons', 'invDistTSS', 'splice', 'frameshift']], kind='reg')#特征间相关性可视化

# %%
sn.boxplot(x='out',y='fitCons',data=GTEx_dataset,orient='v')#绘制箱线图

# %%
sn.boxplot(x='out',y='splice',data=GTEx_dataset,orient='v')#绘制箱线图

# %%
sn.boxplot(x='out',y='invDistTSS',data=GTEx_dataset,orient='v')#绘制箱线图

# %%
#Get shap interaction values
shap_interaction_values = explainer.shap_interaction_values(X)
#Plot heatmap of shap interaction values
print("\nThis is a heatmap for shap interaction values of most important(top 10) features\n")
tmp = np.abs(shap_interaction_values).sum(0)#.sum(0)按列相加
tmp#shape:30*30
for i in range(tmp.shape[0]):
    tmp[i,i] = 0
inds = np.argsort(-tmp.sum(0))[:10]#.argsort数组值从小到大的索引值（取负求和后实际最终获得从大到小）
tmp2 = tmp[inds,:][:,inds]
#seaborn style
sn.clustermap(tmp2,annot=True,cmap= "Reds" ,square=True,figsize=(10,10),xticklabels=X.columns[inds],yticklabels=X.columns[inds])

# %%
#Instances of shap interaction
print("\n#########Two instances of shap interaction are the following########\n")

print("\nFirst instance: Testosterone and Albumin\n")
#Testosterone and Albumin
#shap main effect of Testosterone
print("\nshap main effect of Testosterone")
shap.dependence_plot(
    ("Testosterone", "Testosterone"),
    shap_interaction_values, X,
    display_features=X
)
#SHAP依赖图

# %%
#shap interaction value of Testosterone and Albumin
print("\nshap interaction value of Testosterone and Albumin")
shap.dependence_plot(
    ("Testosterone", "Albumin"),
    shap_interaction_values, X,
    display_features=X
)

# %%
#shap value for Testosterone coloured with expression of Albumin
print("\nshap value for Testosterone coloured with expression of Albumin")
shap.dependence_plot("Testosterone", shap_values, X,interaction_index ="Albumin")

print("\nSecond instance: Cystatin C and Glycated haemoglobin (HbA1c)\n")
#Cystatin C and Glycated haemoglobin (HbA1c)
#shap main effect of Cystatin C
print("\nshap main effect of Cystatin C")
shap.dependence_plot(
    ("Cystatin C", "Cystatin C"),
    shap_interaction_values, X,
    display_features=X
)
#shap interaction value of Cystatin C and Glycated haemoglobin (HbA1c)
print("\nshap interaction value of Cystatin C and Glycated haemoglobin (HbA1c)")
shap.dependence_plot(
    ("Cystatin C", "Glycated haemoglobin (HbA1c)"),
    shap_interaction_values, X,
    display_features=X
)
#shap value for Cystatin C coloured with Glycated haemoglobin (HbA1c)
print("\nshap value for Cystatin C coloured with Glycated haemoglobin (HbA1c)")
shap.dependence_plot("Cystatin C", shap_values, X,interaction_index ="Glycated haemoglobin (HbA1c)")


print("\n...... Finished Model Interpretation ......\n")

# %% [markdown]
# # 回归

# %%
############ Data Processing ###########
print("\n...... Processing Data ......\n")
# Convert varibles with int type to category type
#for idx in GTEx_outlier.select_dtypes(include = ["int64"]).columns:
    #GTEx_outlier[idx] = GTEx_outlier[idx].astype("category")
    
#Input
GTEx_feature_o=GTEx_outlier.drop(['Zscore','N2pair','out','upstream_downstream10kb_200kb','GeneName'],axis=1)
Zout_o=GTEx_outlier['Zscore']
X = copy.deepcopy(GTEx_feature_o)
y = copy.deepcopy(Zout_o)

#TrainingSet : TestSet = 4 : 1
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = SEED)

print("\n...... Finished Data Processing ......\n")
########################################
# Out:
# ...... Processing Data ......
#
#
# ...... Finished Data Processing ......

# %%
########## Model Construction ##########
print("\n...... Training Model ......\n")

# LightGBM params
param_dict = {
    "learning_rate":[0.1, 0.05, 0.02, 0.015, 0.01],
    "num_leaves": range(10,36,5),
    "max_depth" : [-1,2,3,4,5,10,20,40,50],
    "min_data_in_leaf": range(1, 45, 2),
    "feature_fraction" : [i / 10 for i in range(2,11)],
    "metric" : ["l2"],
    "early_stopping_rounds" : [None],
    "n_jobs" : [-1],
    "silent" : [True],
    "verbose" : [-1],
    "n_estimators" : range(50,1000,50),
    "bagging_fraction" :  [i / 10 for i in range(2, 11)],
    "bagging_freq" : [0, 1, 2],
    "lambda_l1" : [0, 0.001, 0.005, 0.01, 0.1],
    "lambda_l2" : [0, 0.001, 0.005, 0.01, 0.1],
    "objective":["regression"],
    "random_state":[2020]
}

#Initiate model
model = lgb.LGBMRegressor()
#Adjust hyper-parameters with 5-fold cross validation (about 45 minutes with 30 CPUs)
rscv = RandomizedSearchCV(model, param_dict, n_iter=100,cv = 5,verbose = 0,
                          scoring = "r2", n_jobs =-1)
rscv.fit(X_train, y_train)   

#save model
joblib.dump(rscv.best_estimator_, "lightgbm_best_model_regression.pkl")
#load model
gbm = joblib.load("lightgbm_best_model_regression.pkl")

print("\n...... Finished Mode Construction ......\n")
######################################
# Out:
# ...... Training Model ......
#
#
# ...... Finished Mode Construction ......

# %%
#Evaluate performance of model
def evaluate_performance_regression(y_test, y_pred):
    # R2
    r2 = metrics.r2_score(y_test,y_pred)
    # Explained Variance Score
    explained_variance_score = metrics.explained_variance_score(y_test, y_pred)
    # Pearson Correlation
    pearson_r,pearson_p = pearsonr(y_pred, y_test)
    # Spearman Correlation
    spearman_r, spearman_p = spearmanr(y_pred, y_test)
    
    model_perf = {"r2":r2,"explained_variance_score":explained_variance_score,
                  "pearson_r":pearson_r,"pearson_p":pearson_p ,
                  "spearman_r":spearman_r,"pearman_p":spearman_p
                 }
    
    return model_perf

# %%
# Output result of evaluation
def eval_output(model_perf,output_file):
    with open(output_file,'w') as f:
        f.write("r2=%s\nexplained_variance_score=%s\npearson_r=%s\tpearson_p=%s\nspearman_r=%s\tpearman_p=%s\n" %
               (model_perf["r2"],model_perf["explained_variance_score"],model_perf["pearson_r"],model_perf["pearson_p"],model_perf["spearman_r"],model_perf["pearman_p"]))

# %%
########## Model Evaluation ##########
print("\n...... Evaluating Model ......\n")

#Get best model with score [max(mean(r2(5 cross validation)))]
best_model = rscv.best_estimator_
#Get predict_value(y_pred) of TestSet
y_pred = best_model.predict(X_test)

#Get model performance
model_perf = evaluate_performance_regression(y_test,y_pred)

#Output result of evaluation
eval_output(model_perf,"./Evaluate_Result_TestSet_regression.txt")
#You can make plot consisted of r2,explained_variance_score,pearson_correlation and spearman_correlation according to the "Evaluate_Result_TestSet.txt"

print("\n...... Finished Model Evaluation ......\n")
######################################
# Out:
# ...... Evaluating Model ......
#
#
# ...... Finished Model Evaluation ......

# %%
######## Model Interpretation ########

print("\n...... Interpreting Model ......\n")

# load JS visualization code to notebook
shap.initjs()
#Explain the model's predictions on the entire dataset for cancer case
explainer = shap.TreeExplainer(rscv.best_estimator_)
shap_values = explainer.shap_values(X)


#Plot the SHAP values of every feature(top 10) for every sample
print("\nThis is an overview of which features are most important(top 10) represented by \
SHAP values of every feature for every sample\n")
shap.summary_plot(shap_values, X, max_display = 10)
#Plot the mean absolute value of the SHAP values for each feature(top 10)
print("\nThis is an overview of which features are most important(top 10) represented by \
 mean absolute value of the SHAP values for each feature\n")
shap.summary_plot(shap_values, X,plot_type="bar",max_display = 10)

#If you want to save shap plot as pdf,just modify the following code
#fig = shap.summary_plot(shap_values, X, show=False,max_display = 10)
#plt.savefig("shap.pdf", format='pdf', dpi=1000, bbox_inches='tight')

#Get shap interaction values
shap_interaction_values = explainer.shap_interaction_values(X)
#Plot heatmap of shap interaction values
print("\nThis is a heatmap for shap interaction values of most important(top 10) features\n")
tmp = np.abs(shap_interaction_values).sum(0)
for i in range(tmp.shape[0]):
    tmp[i,i] = 0
inds = np.argsort(-tmp.sum(0))[:10]
tmp2 = tmp[inds,:][:,inds]
plt.figure(figsize=(12,12))
plt.imshow(tmp2,cmap = "Reds")
plt.yticks(range(tmp2.shape[0]), X.columns[inds], rotation=50.4, horizontalalignment="right")
plt.xticks(range(tmp2.shape[0]), X.columns[inds], rotation=50.4, horizontalalignment="left")
plt.colorbar(fraction=0.045, pad=0.05)
plt.gca().xaxis.tick_top()
plt.show()
# Out:
# ...... Interpreting Model ......
# ...

# %%
############ Data Processing ###########
print("\n...... Processing Data ......\n")
# Convert varibles with int type to category type
#for idx in GTEx_outlier.select_dtypes(include = ["int64"]).columns:
    #GTEx_outlier[idx] = GTEx_outlier[idx].astype("category")
    
#Input
GTEx_feature_c=GTEx_ctr.drop(['Zscore','N2pair','out','upstream_downstream10kb_200kb','GeneName'],axis=1)
Zout_c=GTEx_ctr['Zscore']
X = copy.deepcopy(GTEx_feature_o)
y = copy.deepcopy(Zout_o)

#TrainingSet : TestSet = 4 : 1
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = SEED)

print("\n...... Finished Data Processing ......\n")
########################################
# Out:
# ...... Processing Data ......
#
#
# ...... Finished Data Processing ......

# %%
########## Model Construction ##########
print("\n...... Training Model ......\n")

# LightGBM params
param_dict = {
    "learning_rate":[0.1, 0.05, 0.02, 0.015, 0.01],
    "num_leaves": range(10,36,5),
    "max_depth" : [-1,2,3,4,5,10,20,40,50],
    "min_data_in_leaf": range(1, 45, 2),
    "feature_fraction" : [i / 10 for i in range(2,11)],
    "metric" : ["l2"],
    "early_stopping_rounds" : [None],
    "n_jobs" : [-1],
    "silent" : [True],
    "verbose" : [-1],
    "n_estimators" : range(50,1000,50),
    "bagging_fraction" :  [i / 10 for i in range(2, 11)],
    "bagging_freq" : [0, 1, 2],
    "lambda_l1" : [0, 0.001, 0.005, 0.01, 0.1],
    "lambda_l2" : [0, 0.001, 0.005, 0.01, 0.1],
    "objective":["regression"],
    "random_state":[2020]
}

#Initiate model
model = lgb.LGBMRegressor()
#Adjust hyper-parameters with 5-fold cross validation (about 45 minutes with 30 CPUs)
rscv = RandomizedSearchCV(model, param_dict, n_iter=100,cv = 5,verbose = 0,
                          scoring = "r2", n_jobs =-1)
rscv.fit(X_train, y_train)   

#save model
joblib.dump(rscv.best_estimator_, "lightgbm_best_model_regression_c.pkl")
#load model
gbm = joblib.load("lightgbm_best_model_regression_c.pkl")

print("\n...... Finished Mode Construction ......\n")
######################################
# Out:
# ...... Training Model ......
#
# [LightGBM] [Warning] feature_fraction is set=0.8, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.8
# [LightGBM] [Warning] bagging_fraction is set=1.0, subsample=1.0 will be ignored. Current value: bagging_fraction=1.0
# [LightGBM] [Warning] lambda_l1 is set=0.005, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.005
# [LightGBM] [Warning] min_data_in_leaf is set=7, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=7
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.005, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.005
#
# ...... Finished Mode Construction ......

# %%
########## Model Evaluation ##########
print("\n...... Evaluating Model ......\n")

#Get best model with score [max(mean(r2(5 cross validation)))]
best_model = rscv.best_estimator_
#Get predict_value(y_pred) of TestSet
y_pred = best_model.predict(X_test)

#Get model performance
model_perf = evaluate_performance_regression(y_test,y_pred)

#Output result of evaluation
eval_output(model_perf,"./Evaluate_Result_TestSet_regression_ctr.txt")
#You can make plot consisted of r2,explained_variance_score,pearson_correlation and spearman_correlation according to the "Evaluate_Result_TestSet.txt"

print("\n...... Finished Model Evaluation ......\n")
######################################
# Out:
# ...... Evaluating Model ......
#
#
# ...... Finished Model Evaluation ......

# %%
######## Model Interpretation ########

print("\n...... Interpreting Model ......\n")

# load JS visualization code to notebook
shap.initjs()
#Explain the model's predictions on the entire dataset for cancer case
explainer = shap.TreeExplainer(rscv.best_estimator_)
shap_values = explainer.shap_values(X)


#Plot the SHAP values of every feature(top 10) for every sample
print("\nThis is an overview of which features are most important(top 10) represented by \
SHAP values of every feature for every sample\n")
shap.summary_plot(shap_values, X, max_display = 10)
#Plot the mean absolute value of the SHAP values for each feature(top 10)
print("\nThis is an overview of which features are most important(top 10) represented by \
 mean absolute value of the SHAP values for each feature\n")
shap.summary_plot(shap_values, X,plot_type="bar",max_display = 10)

#If you want to save shap plot as pdf,just modify the following code
#fig = shap.summary_plot(shap_values, X, show=False,max_display = 10)
#plt.savefig("shap.pdf", format='pdf', dpi=1000, bbox_inches='tight')

#Get shap interaction values
shap_interaction_values = explainer.shap_interaction_values(X)
#Plot heatmap of shap interaction values
print("\nThis is a heatmap for shap interaction values of most important(top 10) features\n")
tmp = np.abs(shap_interaction_values).sum(0)
for i in range(tmp.shape[0]):
    tmp[i,i] = 0
inds = np.argsort(-tmp.sum(0))[:10]
tmp2 = tmp[inds,:][:,inds]
plt.figure(figsize=(12,12))
plt.imshow(tmp2,cmap = "Reds")
plt.yticks(range(tmp2.shape[0]), X.columns[inds], rotation=50.4, horizontalalignment="right")
plt.xticks(range(tmp2.shape[0]), X.columns[inds], rotation=50.4, horizontalalignment="left")
plt.colorbar(fraction=0.045, pad=0.05)
plt.gca().xaxis.tick_top()
plt.show()
# Out:
# ...... Interpreting Model ......
# ...
